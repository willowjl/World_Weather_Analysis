# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | coihaique
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | vao
# Processing Record 5 of Set 1 | kaputa
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | lixourion
# Processing Record 8 of Set 1 | fairbanks
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | vikulovo
# Processing Record 11 of Set 1 | acapulco
# Processing Record 12 of Set 1 | puerto madero
# Processing Record 13 of Set 1 | sorrento
# Processing Record 14 of Set 1 | chumikan
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | makokou
# Processing Record 19 of Set 1 | san cristobal
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | chicama
# Processing Record 22 of Set 1 | khuzhir
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | jalu
# Processing Record 25 of Set 1 | cangucu
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | itoman
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | ulladulla
# Processing Record 31 of Set 1 | saint-joseph
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | bonga
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | rocha
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | hambantota
# Processing Record 39 of Set 1 | broome
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | port blair
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | djenne
# Processing Record 48 of Set 1 | nishihara
# Processing Record 49 of Set 1 | stykkisholmur
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | lebyazhye
# Processing Record 10 of Set 2 | comodoro rivadavia
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | sabang
# Processing Record 15 of Set 2 | araouane
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | labytnangi
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | husavik
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | vostok
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | nabire
# Processing Record 27 of Set 2 | broken hill
# Processing Record 28 of Set 2 | shitanjing
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | romny
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | iquique
# Processing Record 36 of Set 2 | limon
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | vila franca do campo
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | toccoa
# Processing Record 42 of Set 2 | yar-sale
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | norrtalje
# Processing Record 46 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | mehamn
# Processing Record 49 of Set 2 | lukulu
# Processing Record 50 of Set 2 | safaga
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | harlingen
# Processing Record 3 of Set 3 | mataura
# Processing Record 4 of Set 3 | jumla
# Processing Record 5 of Set 3 | palapye
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | hay river
# Processing Record 11 of Set 3 | puerto escondido
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | villach
# Processing Record 14 of Set 3 | eenhana
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | torit
# Processing Record 17 of Set 3 | ginir
# Processing Record 18 of Set 3 | bukan
# Processing Record 19 of Set 3 | korla
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | aksarka
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | ilhabela
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | gornopravdinsk
# Processing Record 30 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 3 | camacupa
# Processing Record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | westport
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | vermilion
# Processing Record 40 of Set 3 | sisimiut
# Processing Record 41 of Set 3 | grand gaube
# Processing Record 42 of Set 3 | tromso
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | knysna
# Processing Record 45 of Set 3 | avera
# Processing Record 46 of Set 3 | taseyevo
# Processing Record 47 of Set 3 | watford
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | college
# Processing Record 50 of Set 3 | baykit
# Processing Record 1 of Set 4 | guerrero negro
# Processing Record 2 of Set 4 | wattegama
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | saskylakh
# Processing Record 5 of Set 4 | novyy urengoy
# Processing Record 6 of Set 4 | presidencia roque saenz pena
# Processing Record 7 of Set 4 | muncar
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | sinjai
# Processing Record 10 of Set 4 | elizabeth city
# Processing Record 11 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 4 | ambon
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | valls
# Processing Record 16 of Set 4 | dudinka
# Processing Record 17 of Set 4 | gadsden
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | harper
# Processing Record 20 of Set 4 | kattivakkam
# Processing Record 21 of Set 4 | ziarat
# Processing Record 22 of Set 4 | tabou
# Processing Record 23 of Set 4 | buala
# Processing Record 24 of Set 4 | sokur
# Processing Record 25 of Set 4 | edson
# Processing Record 26 of Set 4 | alibag
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | naples
# Processing Record 31 of Set 4 | mersing
# Processing Record 32 of Set 4 | conceicao do araguaia
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | te anau
# Processing Record 35 of Set 4 | puerto del rosario
# Processing Record 36 of Set 4 | hassleholm
# Processing Record 37 of Set 4 | vryburg
# Processing Record 38 of Set 4 | paamiut
# Processing Record 39 of Set 4 | deputatskiy
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | irbeyskoye
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | bolshaya sosnova
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | anadyr
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | vincennes
# Processing Record 48 of Set 4 | tazovskiy
# Processing Record 49 of Set 4 | beyneu
# Processing Record 50 of Set 4 | hilo
# Processing Record 1 of Set 5 | nyurba
# Processing Record 2 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | ortakoy
# Processing Record 7 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 5 | la zumbadora
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | warrnambool
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | klyuchi
# Processing Record 13 of Set 5 | kaya
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | agua branca
# Processing Record 17 of Set 5 | klichka
# Processing Record 18 of Set 5 | atyrau
# Processing Record 19 of Set 5 | the valley
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | ewa beach
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | gat
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | troitsko-pechorsk
# Processing Record 28 of Set 5 | mosquera
# Processing Record 29 of Set 5 | nova vicosa
# Processing Record 30 of Set 5 | clearwater
# Processing Record 31 of Set 5 | porto nacional
# Processing Record 32 of Set 5 | ponnampet
# Processing Record 33 of Set 5 | necochea
# Processing Record 34 of Set 5 | cedartown
# Processing Record 35 of Set 5 | cilegon
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | santa maria
# Processing Record 38 of Set 5 | fukue
# Processing Record 39 of Set 5 | kapaa
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | sucua
# Processing Record 42 of Set 5 | nipawin
# Processing Record 43 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 5 | san lorenzo
# Processing Record 45 of Set 5 | zyryanka
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | karasuk
# Processing Record 48 of Set 5 | la romana
# Processing Record 49 of Set 5 | khandbari
# Processing Record 50 of Set 5 | bandiagara
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | phalombe
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | phek
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | mount hagen
# Processing Record 8 of Set 6 | salinopolis
# Processing Record 9 of Set 6 | san andres
# Processing Record 10 of Set 6 | gerash
# Processing Record 11 of Set 6 | carballo
# Processing Record 12 of Set 6 | margate
# Processing Record 13 of Set 6 | poyarkovo
# Processing Record 14 of Set 6 | machali
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | meadow lake
# Processing Record 18 of Set 6 | pemba
# Processing Record 19 of Set 6 | emporia
# Processing Record 20 of Set 6 | berezovyy
# Processing Record 21 of Set 6 | saint-pierre
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | russell
# Processing Record 24 of Set 6 | rundu
# Processing Record 25 of Set 6 | forbes
# Processing Record 26 of Set 6 | millau
# Processing Record 27 of Set 6 | el alto
# Processing Record 28 of Set 6 | komsomolskiy
# Processing Record 29 of Set 6 | falaleu
# City not found. Skipping...
# Processing Record 30 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 6 | kolyubakino
# Processing Record 32 of Set 6 | bethlehem
# Processing Record 33 of Set 6 | poum
# Processing Record 34 of Set 6 | big rapids
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | vaitape
# Processing Record 37 of Set 6 | dhanwar
# Processing Record 38 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 6 | ardakan
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | amnat charoen
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | iqaluit
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | toora-khem
# Processing Record 46 of Set 6 | kastamonu
# Processing Record 47 of Set 6 | binga
# Processing Record 48 of Set 6 | manzanillo
# Processing Record 49 of Set 6 | atherton
# Processing Record 50 of Set 6 | veraval
# Processing Record 1 of Set 7 | beatrice
# Processing Record 2 of Set 7 | ciudad guayana
# Processing Record 3 of Set 7 | ypsonas
# Processing Record 4 of Set 7 | maniitsoq
# Processing Record 5 of Set 7 | sao jose da coroa grande
# Processing Record 6 of Set 7 | marinette
# Processing Record 7 of Set 7 | hun
# Processing Record 8 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 7 | chaozhou
# Processing Record 10 of Set 7 | havre
# Processing Record 11 of Set 7 | shatsk
# Processing Record 12 of Set 7 | shahpur
# Processing Record 13 of Set 7 | parras
# City not found. Skipping...
# Processing Record 14 of Set 7 | charters towers
# Processing Record 15 of Set 7 | mindelo
# Processing Record 16 of Set 7 | clacton-on-sea
# Processing Record 17 of Set 7 | kahramanmaras
# Processing Record 18 of Set 7 | cermik
# Processing Record 19 of Set 7 | kenora
# Processing Record 20 of Set 7 | evensk
# Processing Record 21 of Set 7 | maceio
# Processing Record 22 of Set 7 | zabol
# Processing Record 23 of Set 7 | elliot lake
# Processing Record 24 of Set 7 | baherden
# Processing Record 25 of Set 7 | caravelas
# Processing Record 26 of Set 7 | rincon
# Processing Record 27 of Set 7 | port lincoln
# Processing Record 28 of Set 7 | port hardy
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 7 | valley
# Processing Record 32 of Set 7 | saint anthony
# Processing Record 33 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 34 of Set 7 | dolores
# Processing Record 35 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 7 | longfeng
# Processing Record 37 of Set 7 | yerbogachen
# Processing Record 38 of Set 7 | strakonice
# Processing Record 39 of Set 7 | garowe
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | bathurst
# Processing Record 42 of Set 7 | bemidji
# Processing Record 43 of Set 7 | kondinskoye
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 7 | bahia honda
# Processing Record 47 of Set 7 | berlevag
# Processing Record 48 of Set 7 | mlalo
# Processing Record 49 of Set 7 | salalah
# Processing Record 50 of Set 7 | hoi an
# Processing Record 1 of Set 8 | kaeo
# Processing Record 2 of Set 8 | elat
# Processing Record 3 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 8 | san patricio
# Processing Record 6 of Set 8 | sherman
# Processing Record 7 of Set 8 | cassilandia
# Processing Record 8 of Set 8 | coruripe
# Processing Record 9 of Set 8 | samarai
# Processing Record 10 of Set 8 | constitucion
# Processing Record 11 of Set 8 | bonthe
# Processing Record 12 of Set 8 | pingzhuang
# Processing Record 13 of Set 8 | mount gambier
# Processing Record 14 of Set 8 | mao
# Processing Record 15 of Set 8 | zharkent
# Processing Record 16 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 8 | portland
# Processing Record 18 of Set 8 | nakhon phanom
# Processing Record 19 of Set 8 | ust-maya
# Processing Record 20 of Set 8 | barra do garcas
# Processing Record 21 of Set 8 | pula
# Processing Record 22 of Set 8 | chardara
# Processing Record 23 of Set 8 | wanning
# Processing Record 24 of Set 8 | tarakan
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | lata
# Processing Record 27 of Set 8 | tarauaca
# Processing Record 28 of Set 8 | touros
# Processing Record 29 of Set 8 | abha
# Processing Record 30 of Set 8 | wukari
# Processing Record 31 of Set 8 | santa rosalia
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | sovetskiy
# Processing Record 34 of Set 8 | landerneau
# Processing Record 35 of Set 8 | aleksandrov gay
# Processing Record 36 of Set 8 | riyadh
# Processing Record 37 of Set 8 | alipur duar
# City not found. Skipping...
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | lavrentiya
# Processing Record 40 of Set 8 | alyangula
# Processing Record 41 of Set 8 | tilichiki
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | la ronge
# Processing Record 44 of Set 8 | soderhamn
# Processing Record 45 of Set 8 | kadoma
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | novikovo
# Processing Record 48 of Set 8 | xian
# Processing Record 49 of Set 8 | mogadishu
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | hwange
# Processing Record 2 of Set 9 | stornoway
# Processing Record 3 of Set 9 | buraydah
# Processing Record 4 of Set 9 | corinth
# Processing Record 5 of Set 9 | hovd
# Processing Record 6 of Set 9 | emba
# Processing Record 7 of Set 9 | suffolk
# Processing Record 8 of Set 9 | polunochnoye
# Processing Record 9 of Set 9 | rio rancho
# Processing Record 10 of Set 9 | almonte
# Processing Record 11 of Set 9 | norman wells
# Processing Record 12 of Set 9 | kirkuk
# Processing Record 13 of Set 9 | pangai
# Processing Record 14 of Set 9 | faya
# Processing Record 15 of Set 9 | maumere
# Processing Record 16 of Set 9 | kargasok
# Processing Record 17 of Set 9 | ntungamo
# Processing Record 18 of Set 9 | west bay
# Processing Record 19 of Set 9 | soyo
# Processing Record 20 of Set 9 | rosarito
# Processing Record 21 of Set 9 | teloloapan
# Processing Record 22 of Set 9 | gazimurskiy zavod
# Processing Record 23 of Set 9 | benjamin aceval
# Processing Record 24 of Set 9 | butia
# Processing Record 25 of Set 9 | blagoveshchenka
# Processing Record 26 of Set 9 | porbandar
# Processing Record 27 of Set 9 | santiago del estero
# Processing Record 28 of Set 9 | hasaki
# Processing Record 29 of Set 9 | awjilah
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | lakes entrance
# Processing Record 33 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 9 | castro
# Processing Record 35 of Set 9 | tuy hoa
# Processing Record 36 of Set 9 | manono
# Processing Record 37 of Set 9 | severo-kurilsk
# Processing Record 38 of Set 9 | los llanos de aridane
# Processing Record 39 of Set 9 | ratnagiri
# Processing Record 40 of Set 9 | amapa
# Processing Record 41 of Set 9 | butembo
# Processing Record 42 of Set 9 | paita
# Processing Record 43 of Set 9 | meulaboh
# Processing Record 44 of Set 9 | nakusp
# Processing Record 45 of Set 9 | dhidhdhoo
# Processing Record 46 of Set 9 | yulara
# Processing Record 47 of Set 9 | maun
# Processing Record 48 of Set 9 | seymchan
# Processing Record 49 of Set 9 | sunyani
# Processing Record 50 of Set 9 | beira
# Processing Record 1 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 10 | machilipatnam
# Processing Record 3 of Set 10 | puerto ayacucho
# Processing Record 4 of Set 10 | vila
# Processing Record 5 of Set 10 | roald
# Processing Record 6 of Set 10 | ucluelet
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | mikhaylovka
# Processing Record 9 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 10 | obo
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | kyra
# Processing Record 13 of Set 10 | angra
# City not found. Skipping...
# Processing Record 14 of Set 10 | ouargaye
# Processing Record 15 of Set 10 | ambulu
# Processing Record 16 of Set 10 | odweyne
# Processing Record 17 of Set 10 | lorengau
# Processing Record 18 of Set 10 | bengkulu
# Processing Record 19 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 10 | ayan
# Processing Record 21 of Set 10 | svetlaya
# Processing Record 22 of Set 10 | xichang
# Processing Record 23 of Set 10 | byron bay
# Processing Record 24 of Set 10 | mezen
# Processing Record 25 of Set 10 | haines junction
# Processing Record 26 of Set 10 | raga
# Processing Record 27 of Set 10 | siirt
# Processing Record 28 of Set 10 | xining
# Processing Record 29 of Set 10 | radenci
# Processing Record 30 of Set 10 | colares
# Processing Record 31 of Set 10 | kumbo
# Processing Record 32 of Set 10 | derzhavinsk
# Processing Record 33 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 10 | san quintin
# Processing Record 35 of Set 10 | liberal
# Processing Record 36 of Set 10 | pavlovka
# Processing Record 37 of Set 10 | seminole
# Processing Record 38 of Set 10 | arrifes
# Processing Record 39 of Set 10 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 40 of Set 10 | sharon
# Processing Record 41 of Set 10 | whitecourt
# Processing Record 42 of Set 10 | nhulunbuy
# Processing Record 43 of Set 10 | jacareacanga
# Processing Record 44 of Set 10 | birin
# Processing Record 45 of Set 10 | mudgee
# Processing Record 46 of Set 10 | mareeba
# Processing Record 47 of Set 10 | olavarria
# Processing Record 48 of Set 10 | walvis bay
# Processing Record 49 of Set 10 | villazon
# Processing Record 50 of Set 10 | matadi
# Processing Record 1 of Set 11 | santa barbara
# Processing Record 2 of Set 11 | ampanihy
# Processing Record 3 of Set 11 | isiro
# Processing Record 4 of Set 11 | kieta
# Processing Record 5 of Set 11 | bandar-e lengeh
# Processing Record 6 of Set 11 | verkhoyansk
# Processing Record 7 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 11 | disraeli
# Processing Record 9 of Set 11 | alvinopolis
# Processing Record 10 of Set 11 | zholymbet
# Processing Record 11 of Set 11 | wajima
# Processing Record 12 of Set 11 | tigzirt
# Processing Record 13 of Set 11 | tucuman
# Processing Record 14 of Set 11 | karimpur
# Processing Record 15 of Set 11 | erseke
# Processing Record 16 of Set 11 | stubbekobing
# Processing Record 17 of Set 11 | marakkanam
# Processing Record 18 of Set 11 | vanavara
# Processing Record 19 of Set 11 | ixtapa
# Processing Record 20 of Set 11 | warburg
# Processing Record 21 of Set 11 | katsuura
# Processing Record 22 of Set 11 | varhaug
# Processing Record 23 of Set 11 | ascension
# Processing Record 24 of Set 11 | key largo
# Processing Record 25 of Set 11 | blyznyuky
# Processing Record 26 of Set 11 | concarneau
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | aquiraz
# Processing Record 29 of Set 11 | formosa
# Processing Record 30 of Set 11 | marzuq
# Processing Record 31 of Set 11 | aykhal
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 11 | shimanovsk
# Processing Record 35 of Set 11 | dankov
# Processing Record 36 of Set 11 | sinnamary
# Processing Record 37 of Set 11 | svetlogorsk
# Processing Record 38 of Set 11 | belaya gora
# Processing Record 39 of Set 11 | gravdal
# Processing Record 40 of Set 11 | mwinilunga
# Processing Record 41 of Set 11 | hirara
# Processing Record 42 of Set 11 | tiarei
# Processing Record 43 of Set 11 | kikwit
# Processing Record 44 of Set 11 | port augusta
# Processing Record 45 of Set 11 | hokitika
# Processing Record 46 of Set 11 | namie
# Processing Record 47 of Set 11 | kabarnet
# Processing Record 48 of Set 11 | batagay-alyta
# Processing Record 49 of Set 11 | saint-augustin
# Processing Record 50 of Set 11 | biloela
# Processing Record 1 of Set 12 | santa fe
# Processing Record 2 of Set 12 | chadan
# Processing Record 3 of Set 12 | smidovich
# Processing Record 4 of Set 12 | beringovskiy
# Processing Record 5 of Set 12 | likhoy
# Processing Record 6 of Set 12 | bontang
# Processing Record 7 of Set 12 | kununurra
# Processing Record 8 of Set 12 | mandalgovi
# Processing Record 9 of Set 12 | dicabisagan
# Processing Record 10 of Set 12 | lichinga
# Processing Record 11 of Set 12 | koshurnikovo
# Processing Record 12 of Set 12 | finote selam
# Processing Record 13 of Set 12 | el penol
# Processing Record 14 of Set 12 | mariental
# Processing Record 15 of Set 12 | juan lacaze
# Processing Record 16 of Set 12 | belyy yar
# Processing Record 17 of Set 12 | nizwa
# Processing Record 18 of Set 12 | atambua
# Processing Record 19 of Set 12 | nizhniy kuranakh
# Processing Record 20 of Set 12 | caramay
# Processing Record 21 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 22 of Set 12 | sangar
# Processing Record 23 of Set 12 | kropotkin
# Processing Record 24 of Set 12 | ekuvukeni
# Processing Record 25 of Set 12 | kiunga
# Processing Record 26 of Set 12 | fatehpur
# Processing Record 27 of Set 12 | canutama
# Processing Record 28 of Set 12 | hohhot
# Processing Record 29 of Set 12 | saint albans
# Processing Record 30 of Set 12 | amga
# Processing Record 31 of Set 12 | kahului
# Processing Record 32 of Set 12 | iskateley
# Processing Record 33 of Set 12 | saiha
# Processing Record 34 of Set 12 | tayu
# Processing Record 35 of Set 12 | jinji
# Processing Record 36 of Set 12 | takaka
# Processing Record 37 of Set 12 | aasiaat
# Processing Record 38 of Set 12 | koch bihar
# Processing Record 39 of Set 12 | plettenberg bay
# Processing Record 40 of Set 12 | brae
# Processing Record 41 of Set 12 | konotop
# Processing Record 42 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 12 | lagos
# Processing Record 44 of Set 12 | bhola
# Processing Record 45 of Set 12 | bobrovka
# Processing Record 46 of Set 12 | matola
# Processing Record 47 of Set 12 | kharagauli
# Processing Record 48 of Set 12 | armizonskoye
# Processing Record 49 of Set 12 | ihosy
# Processing Record 50 of Set 12 | nouadhibou
# Processing Record 1 of Set 13 | yeniseysk
# Processing Record 2 of Set 13 | uray
# Processing Record 3 of Set 13 | turbo
# Processing Record 4 of Set 13 | lakhimpur
# Processing Record 5 of Set 13 | beloha
# Processing Record 6 of Set 13 | tyrma
# Processing Record 7 of Set 13 | caranavi
# Processing Record 8 of Set 13 | terrace
# Processing Record 9 of Set 13 | monkey hill
# Processing Record 10 of Set 13 | hariana
# Processing Record 11 of Set 13 | jinchang
# Processing Record 12 of Set 13 | banting
# Processing Record 13 of Set 13 | san ramon de la nueva oran
# Processing Record 14 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 15 of Set 13 | yamada
# Processing Record 16 of Set 13 | nanakuli
# Processing Record 17 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 18 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 13 | taltal
# Processing Record 20 of Set 13 | galesong
# Processing Record 21 of Set 13 | toms river
# Processing Record 22 of Set 13 | cap malheureux
# Processing Record 23 of Set 13 | jiangyou
# Processing Record 24 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 13 | ibotirama
# Processing Record 26 of Set 13 | bonavista
# Processing Record 27 of Set 13 | turbat
# Processing Record 28 of Set 13 | cap-aux-meules
# Processing Record 29 of Set 13 | utashinai
# Processing Record 30 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 13 | belmonte
# Processing Record 32 of Set 13 | gold coast
# Processing Record 33 of Set 13 | port macquarie
# Processing Record 34 of Set 13 | udachnyy
# Processing Record 35 of Set 13 | yablonovo
# Processing Record 36 of Set 13 | lichtenburg
# Processing Record 37 of Set 13 | lengshuijiang
# Processing Record 38 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 13 | san pablo
# Processing Record 40 of Set 13 | ahipara
# Processing Record 41 of Set 13 | quesnel
# Processing Record 42 of Set 13 | prabumulih
# Processing Record 43 of Set 13 | bauta
# Processing Record 44 of Set 13 | kolyvan
# Processing Record 45 of Set 13 | akdepe
# Processing Record 46 of Set 13 | coswig
# Processing Record 47 of Set 13 | olga
# Processing Record 48 of Set 13 | riberalta
# Processing Record 49 of Set 13 | yabassi
# Processing Record 50 of Set 13 | sur
# Processing Record 1 of Set 14 | estelle
# Processing Record 2 of Set 14 | kirakira
# Processing Record 3 of Set 14 | honningsvag
# Processing Record 4 of Set 14 | portree
# Processing Record 5 of Set 14 | axim
# Processing Record 6 of Set 14 | methoni
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | bongaree
# Processing Record 9 of Set 14 | swift current
# Processing Record 10 of Set 14 | monrovia
# Processing Record 11 of Set 14 | henties bay
# Processing Record 12 of Set 14 | sydney mines
# Processing Record 13 of Set 14 | sistranda
# Processing Record 14 of Set 14 | chebenki
# Processing Record 15 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 16 of Set 14 | laki
# Processing Record 17 of Set 14 | manaus
# Processing Record 18 of Set 14 | basco
# Processing Record 19 of Set 14 | fortuna foothills
# Processing Record 20 of Set 14 | lasa
# Processing Record 21 of Set 14 | buffalo
# Processing Record 22 of Set 14 | batemans bay
# Processing Record 23 of Set 14 | gazanjyk
# Processing Record 24 of Set 14 | boyuibe
# Processing Record 25 of Set 14 | tecoanapa
# Processing Record 26 of Set 14 | qaqortoq
# Processing Record 27 of Set 14 | parintins
# Processing Record 28 of Set 14 | okha
# Processing Record 29 of Set 14 | agadir
# Processing Record 30 of Set 14 | andenes
# Processing Record 31 of Set 14 | yueyang
# Processing Record 32 of Set 14 | wilkes-barre
# Processing Record 33 of Set 14 | vernon
# Processing Record 34 of Set 14 | pogranichnyy
# Processing Record 35 of Set 14 | areni
# Processing Record 36 of Set 14 | tselinnoye
# Processing Record 37 of Set 14 | prieska
# Processing Record 38 of Set 14 | freetown
# Processing Record 39 of Set 14 | thaton
# Processing Record 40 of Set 14 | solano
# Processing Record 41 of Set 14 | plaster rock
# Processing Record 42 of Set 14 | matamoros
# Processing Record 43 of Set 14 | ulaangom
# Processing Record 44 of Set 14 | codajas
# Processing Record 45 of Set 14 | la asuncion
# Processing Record 46 of Set 14 | chilca
# Processing Record 47 of Set 14 | havoysund
# Processing Record 48 of Set 14 | verkhnetulomskiy
# Processing Record 49 of Set 14 | kawhia
# Processing Record 50 of Set 14 | puerto colombia
# Processing Record 1 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 15 | sao felix do xingu
# Processing Record 3 of Set 15 | toritama
# Processing Record 4 of Set 15 | carikar
# City not found. Skipping...
# Processing Record 5 of Set 15 | poso
# Processing Record 6 of Set 15 | adrar
# Processing Record 7 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 15 | horodnytsya
# Processing Record 9 of Set 15 | itarema
# Processing Record 10 of Set 15 | nuuk
# Processing Record 11 of Set 15 | bilma
# Processing Record 12 of Set 15 | placido de castro
# Processing Record 13 of Set 15 | yafran
# Processing Record 14 of Set 15 | morant bay
# Processing Record 15 of Set 15 | kon tum
# Processing Record 16 of Set 15 | alofi
# Processing Record 17 of Set 15 | sambava
# Processing Record 18 of Set 15 | mayo
# Processing Record 19 of Set 15 | gao
# Processing Record 20 of Set 15 | halol
# Processing Record 21 of Set 15 | sailana
# Processing Record 22 of Set 15 | port hedland
# Processing Record 23 of Set 15 | camana
# Processing Record 24 of Set 15 | faranah
# Processing Record 25 of Set 15 | angoche
# Processing Record 26 of Set 15 | usinsk
# Processing Record 27 of Set 15 | poindimie
# Processing Record 28 of Set 15 | marawi
# Processing Record 29 of Set 15 | alta floresta
# Processing Record 30 of Set 15 | ponta delgada
# Processing Record 31 of Set 15 | toucheng
# Processing Record 32 of Set 15 | tual
# Processing Record 33 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 15 | canico
# Processing Record 35 of Set 15 | roros
# Processing Record 36 of Set 15 | dunedin
# Processing Record 37 of Set 15 | andreyevo
# Processing Record 38 of Set 15 | okhotsk
# Processing Record 39 of Set 15 | yen bai
# Processing Record 40 of Set 15 | saint-louis
# Processing Record 41 of Set 15 | palana
# Processing Record 42 of Set 15 | dayong
# Processing Record 43 of Set 15 | strathroy
# Processing Record 44 of Set 15 | rzhyshchiv
# Processing Record 45 of Set 15 | safranbolu
# Processing Record 46 of Set 15 | la macarena
# Processing Record 47 of Set 15 | mariinsk
# Processing Record 48 of Set 15 | bairiki
# Processing Record 49 of Set 15 | teguise
# Processing Record 50 of Set 15 | erzin
# Processing Record 1 of Set 16 | lazaro cardenas
# Processing Record 2 of Set 16 | ibanda
# Processing Record 3 of Set 16 | ambilobe
# Processing Record 4 of Set 16 | talaya
# Processing Record 5 of Set 16 | vanimo
# Processing Record 6 of Set 16 | salto
# Processing Record 7 of Set 16 | tirthahalli
# Processing Record 8 of Set 16 | bubaque
# Processing Record 9 of Set 16 | umm kaddadah
# Processing Record 10 of Set 16 | fallon
# Processing Record 11 of Set 16 | maldonado
# Processing Record 12 of Set 16 | pavagada
# Processing Record 13 of Set 16 | raudeberg
# Processing Record 14 of Set 16 | codrington
# Processing Record 15 of Set 16 | waipawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Airai      TL  -8.9266  125.4092     78.60        39          87
# 1       Coihaique      CL -45.5752  -72.0662     48.81        81          75
# 2     East London      ZA -33.0153   27.9116     71.91        85         100
# 3             Vao      NC -22.6667  167.4833     76.82        70          10
# 4          Kaputa      ZM  -8.4689   29.6619     66.07        88          98
# 5  Port Elizabeth      ZA -33.9180   25.5701     73.09        97          75
# 6       Lixourion      GR  38.2019   20.4314     59.85        67          25
# 7       Fairbanks      US  64.8378 -147.7164     15.22        83         100
# 8           Lagoa      PT  39.0500  -27.9833     62.42        83           0
# 9        Vikulovo      RU  56.8167   70.6107     15.67        92         100
#
#    Wind Speed Current Description
# 0        0.98     overcast clouds
# 1        4.61          light rain
# 2       21.79     overcast clouds
# 3       15.05           clear sky
# 4        3.98          light rain
# 5       19.57       broken clouds
# 6       11.48    scattered clouds
# 7        3.44     overcast clouds
# 8       37.45           clear sky
# 9       14.23          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
